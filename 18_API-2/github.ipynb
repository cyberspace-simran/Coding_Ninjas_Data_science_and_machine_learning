# %% [raw]
# github organisation repo
# Send Feedback
# Fetch the all repositories(except Forked repository) of organisation ‘CodingNinjasCodes’ from Github API using OAuth(access token)
# Print the name of repository with its watch count and fork count.
# Output Format:
# repo_name1 watch_count1 fork_count1
# repo_name2 watch_count2 fork_count2
# . . .
# . . .

# %% [raw]
# be016e0484b2fb9f2ae9528cea125bcdf0a00ee7

# %% [raw]
# e4beb344b41423b74165
# ed04963be7fc429df0b0aa17cc4e23667da85b99

# %%
import requests
import json

data={"client_id":"e4beb344b41423b74165", "state":"Successful", "redirect_uri":"https://www.google.com"}
response=requests.get('https://github.com/login/oauth/authorize', params=data)
print(response.url)
# Out:
# https://github.com/login?client_id=e4beb344b41423b74165&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3De4beb344b41423b74165%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26state%3DSuccessful

# %% [raw]
# https://www.google.com/?code=d73f9b2be3b649d7133a&state=Successful

# %%
data={"client_id":"e4beb344b41423b74165", "client_secret":"ed04963be7fc429df0b0aa17cc4e23667da85b99",
     "code":"d73f9b2be3b649d7133a", "redirect_uri":"https://www.google.com", "state":"Successful"}
r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
print(r.text)
# Out:
# {"access_token":"0d7bd3fd5ae4c0116ae3d1ba6a45d1a0e63ccde8","token_type":"bearer","scope":""}

# %%
r=requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',
               headers={"Authorization":"token 0d7bd3fd5ae4c0116ae3d1ba6a45d1a0e63ccde8"})
data=r.json()

# %%
data
# Out:
# [{'id': 68499062,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2ODQ5OTA2Mg==',
#   'name': 'SmoothScrollJs',
#   'full_name': 'CodingNinjasCodes/SmoothScrollJs',
#   'private': False,
#   'owner': {'login': 'CodingNinjasCodes',
#    'id': 22269960,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMjY5OTYw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22269960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodingNinjasCodes',
#    'html_url': 'https://github.com/CodingNinjasCodes',
#    'followers_url': 'https://api.github.com/users/CodingNinjasCodes/followers',
#    'following_url': 'https://api.github.com/users/CodingNinjasCodes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CodingNinjasCodes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CodingNinjasCodes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CodingNinjasCodes/subscriptions',
# ...

# %%
l=[]
for i in data:
    if not i['fork']:
        l.append([i['name'], i['watchers_count'], i['forks_count']])
l
# Out:
# [['SmoothScrollJs', 16, 5],
#  ['RubyTutorial', 14, 9],
#  ['Python3Tutorial', 5, 3],
#  ['HTMLandCssNotes', 14, 23],
#  ['Beacathon', 2, 8],
#  ['JSNotes', 5, 6],
#  ['learnml', 1, 0],
#  ['RubyNotebook', 2, 5],
#  ['InterQues', 71, 160],
#  ['coderoom', 4, 3]]

# %%
import requests
import json

# data={"client_id":"e4beb344b41423b74165", "state":"Successful", "redirect_uri":"https://www.google.com"}
# response=requests.get('https://github.com/login/oauth/authorize', params=data)
# print(response.url)
# data={"client_id":"e4beb344b41423b74165", "client_secret":"ed04963be7fc429df0b0aa17cc4e23667da85b99",
#      "code":"d73f9b2be3b649d7133a", "redirect_uri":"https://www.google.com", "state":"Successful"}
# r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
# print(r.text)
r=requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',
               headers={"Authorization":"token 0d7bd3fd5ae4c0116ae3d1ba6a45d1a0e63ccde8"})
data=r.json()
l=[]

for t in data:
    if t['fork'] == False:
        print(t['name'],t['watchers_count'],t['forks_count'])
# Out:
# SmoothScrollJs 16 5
# RubyTutorial 14 9
# Python3Tutorial 5 3
# HTMLandCssNotes 14 23
# Beacathon 2 8
# JSNotes 5 6
# learnml 1 0
# RubyNotebook 2 5
# InterQues 71 160
# coderoom 4 3

# %%
import requests
import json
response2 = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/contributors')
members = response2.json()
for t in members:
    print(t['login'],t['contributions'])
# Out:
# Sherawat42 17
# Rawal27 13
# tushartuteja 8

# %%
r=requests.get('https://api.github.com/orgs/CodingNinjasCodes/contributors',
               headers={"Authorization":"token 0d7bd3fd5ae4c0116ae3d1ba6a45d1a0e63ccde8"})
data=r.json()
data
# Out:
# {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest'}

# %%
for i in data:
    print(i['author']['login'], i['total'])
# Out:
# tushartuteja 5
# Rawal27 13
# Sherawat42 15

# %% [raw]
# import requests
# import json
#
# data={"client_id":"171b2fccb73d64507b96", "redirect_uri":"https://www.google.com", "state":"Welcome", "scope":"repo"}
# response=requests.get('https://github.com/login/oauth/authorize', params=data)
# print(response.url)
#
#
# data={"client_id":"171b2fccb73d64507b96", "client_secret":"58e5b908893c969d63e9d87ecb8d72011032a611",
#      "code":"7b27ff11caafdad15895", "redirect_uri":"https://www.google.com", "state":"Welcome"}
# r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
# print(r.text)
#
# data={"name":"OAuth_Repository", "auto_init":True}
# r=requests.post('https://api.github.com/user/repos', data=json.dumps(data),
#                headers={"Authorization":"token 7e64f636f1b012a439308319dc2a5d75f425aa7e"})
# r.status_code

# %%
import requests
import json


# e4beb344b41423b74165
# ed04963be7fc429df0b0aa17cc4e23667da85b99


data={"client_id":"e4beb344b41423b74165", "redirect_uri":"https://www.google.com", "state":"Welcome", "scope":"repo"}
response=requests.get('https://github.com/login/oauth/authorize', params=data)
print(response.url)
# Out:
# https://github.com/login?client_id=e4beb344b41423b74165&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3De4beb344b41423b74165%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26scope%3Drepo%26state%3DWelcome

# %%
# https://www.google.com/?code=66a19807919037d787b1&state=Welcome
data={"client_id":"e4beb344b41423b74165", "client_secret":"ed04963be7fc429df0b0aa17cc4e23667da85b99",
     "code":"66a19807919037d787b1", "redirect_uri":"https://www.google.com", "state":"Welcome"}
r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
print(r.text)
# Out:
# {"access_token":"2ae0c4955107cf4bc9b31448607330d98a11559b","token_type":"bearer","scope":"repo"}

# %%
data={"name":"OAuth_Made_Repository", "auto_init":True}
r=requests.post('https://api.github.com/user/repos', data=json.dumps(data),
               headers={"Authorization":"token 2ae0c4955107cf4bc9b31448607330d98a11559b"})
r.status_code
# Out:
# 201

# %%
r=requests.get('https://api.github.com/orgs/CodingNinjasCodes/SmoothScrollJs',
               headers={"Authorization":"token 2ae0c4955107cf4bc9b31448607330d98a11559b"})
data=r.json()
data
# Out:
# {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest'}

# %%
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=1&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token 2ae0c4955107cf4bc9b31448607330d98a11559b"})
data=r.json()

data
# Out:
# [{'id': 4132843,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTMyODQz',
#   'name': 'x-mario',
#   'full_name': 'fossasia/x-mario',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fossasia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fossasia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fossasia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fossasia/orgs',
#    'repos_url': 'https://api.github.com/users/fossasia/repos',
# ...

# %%
l3=[]
count=0
for i in data:
    l3.append(i['name'])
    count+=1
print(count)
# Out:
# 100

# %%
final_list=[l, l2, l3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-33dff71dbeb0> in <module>
# ----> 1 final_list=[l, l2, l3]
#
# NameError: name 'l2' is not defined

# %%
l2=[]
count=0
for i in data2:
    l2.append(i['name'])
    count+=1
print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5868aa731e05> in <module>
#       1 l2=[]
#       2 count=0
# ----> 3 for i in data2:
#       4     l2.append(i['name'])
#       5     count+=1
#
# NameError: name 'data2' is not defined

# %%
l=[]
count=0
for i in data:
    l.append(i['name'])
    count+=1
print(count)
100
In [49]:
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=2&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token cd0653b525c887c01bf74c2d5477e3e85821503b"})
data2=r.json()

data2
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=3&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token cd0653b525c887c01bf74c2d5477e3e85821503b"})
data3=r.json()

data3
# Out:
#   File "<ipython-input-26-9cd9c13157eb>", line 8
#     In [49]:
#             ^
# SyntaxError: invalid syntax

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json
token='63d8b93fd1689e1a34f9ec7c6a4420d315cbdd38'
headers={'Authorization': 'token '+token}
response=requests.get('https://api.github.com/orgs/fossasia',headers=headers)
number_repo=response.json().get('public_repos')
for i in range(1,number_repo//30 +2,1):
    data={'type':'all','page':i}
    response=requests.get('https://api.github.com/orgs/fossasia/repos',headers=headers,params=data)
    for j in response.json():
        print(j.get('name'))
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# knitlib
# pslab-expeyes
# timeline.api.fossasia.net
# 2016.fossasia.org
# fossasia.org
# pslab-sister
# ...
